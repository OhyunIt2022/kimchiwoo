# %%
array=[1,2,3,4,5]
print(array)
# Out:
# [1, 2, 3, 4, 5]

# %%
array.append(6)
print(array)
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
array.append(7,8)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-4-3337635a3bd6> in <module>()
# ----> 1 array.append(7,8)
#
# TypeError: append() takes exactly one argument (2 given)

# %%
array.append([1,2])
print(array)
# Out:
# [1, 2, 3, 4, 5, 6, [1, 2]]

# %%
dir(array)
# Out:
# ['__add__',
#  '__class__',
#  '__contains__',
#  '__delattr__',
#  '__delitem__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__reversed__',
#  '__rmul__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'append',
#  'clear',
#  'copy',
#  'count',
#  'extend',
#  'index',
#  'insert',
#  'pop',
#  'remove',
#  'reverse',
#  'sort']

# %%
ar2=[3,10,19,100,1,7]
print(ar2)
# Out:
# [3, 10, 19, 100, 1, 7]

# %%
ar2.sort()
print(ar2)
# Out:
# [1, 3, 7, 10, 19, 100]

# %%
ar3=['z','c','d','가','나','다']
print(ar3)
# Out:
# ['z', 'c', 'd', '가', '나', '다']

# %%
ar4=[5,3,1,[1,2,3]]
print(ar4)
# Out:
# [5, 3, 1, [1, 2, 3]]

# %%
ar4.reverse()
print(ar4)
# Out:
# [1, 3, 5]

# %%
ar4=[5,3,1,[1,2,3]]
ar4[3].reverse()
ar4.reverse()
print(ar4)
# Out:
# [[3, 2, 1], 1, 3, 5]

# %%
ar5=[1,2,3,4,5]
in5=ar5.index(4)
print(in5)
# Out:
# 3

# %% [markdown]
# in1=ar5.index(1)
# in5=ar5.index(5)
# ar=ar5[in1:in5]
# print(ar)

# %%
ar5.insert(in5,9)
print(ar5)
# Out:
# [1, 2, 3, 4, 9, 5]

# %%
ar5.pop()
print(ar5)
# Out:
# [1, 2, 3, 4]

# %%
ar6=[1,1,1,2,3,4,4,'hi','hi',1,2]
chi=ar6.count('hi')
print(chi)
# Out:
# 2

# %%
c1=ar6.count(1)
print(c1)
# Out:
# 4

# %%
ar7=[1,2,3]
ar8=[1,2,3]
ar7.extend(ar8)
print(ar7)
# Out:
# [1, 2, 3, 1, 2, 3]

# %%
ar9=[1,2,3]
ar10=ar9

# %%
tp=(1,2,3)
print(tp)
# Out:
# (1, 2, 3)

# %%
sp=[1,2,3]
print(sp)
del sp[0]
print(sp)
# Out:
# [1, 2, 3]
# [2, 3]

# %%
tp1=(1,2,3,[1,2,3])
tp1[-1][0]=10
print(tp1)
# Out:
# (1, 2, 3, [10, 2, 3])

# %%
dir(tuple)
# Out:
# ['__add__',
#  '__class__',
#  '__contains__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getnewargs__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rmul__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'count',
#  'index']

# %%
len(tp)
# Out:
# 3

# %%
dic={'키','값'}
print(dic)
# Out:
# {'키', '값'}

# %%
회원정보={'이름':'김치우','번호':'01000000000','성별':'남'}
print(회원정보['이름'])
# Out:
# 김치우

# %%
회원정보.keys()
# Out:
# dict_keys(['이름', '번호', '성별'])

# %%
샘플딕셔너리={"배열":[1,2,3]}
배열get = 샘플딕셔너리.get("배열1")
배열키로가져오기=샘플딕셔너리['배열1']

# %%
print(True)
# Out:
# True
